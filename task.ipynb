# %%
knn used for classification problrm recomedation sysytem and patter recoginziation 
examples: movie recomandation consumer segementation handwriting identification disesae detection

what is knnK-Nearest Neighbor
knnn woorks to the similarity and distance btw points
it donot have any equation 

how knn works
step 1:choose the k value 
(ex :3 k value 3 nearest data points)
step2: find nearest k  neighbours
ex(3 nearest dtata points)
step 3: check majority classes among the neigbhours
step 4: assing predicted class
    

    works based and distannce and similarity
    classification and regresssion both are going to work 

    distance metrics: knn dependents on tyhe diostance 
    1 eucledean distance : squrt((x2-x1)^2 + (y2-y1)^2)
    X1=2
    Y1=3
    X2=6
    Y2=7

    distance = sqrt((6-2)^2 + (7-3)^2)

# %%
X1=2
Y1=3
X2=6
Y2=7
distance = sqrt((6-2)^2 + (7-3)^2)
Print(distance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 X2=6
#       4 Y2=7
# ----> 5 distance = sqrt((6-2)^2 + (7-3)^2)
#       6 Print(distance)
#
# NameError: name 'sqrt' is not defined

# %%
1.eucledean distance : squrt((x2-x1)^2 + (y2-y1)^2)-contnous numerical data
2.manhattan distance : abs(x2-x1) + abs(y2-y1)-grid based data
3.minkowski distance : generalization of eucledean and manhattan distance
4.hamming distance : number of positions at which the corresponding symbols are different -categorical data

# %%
how to choose k value?
small k vale leads to overfitting and
large k value leads to underfitting
cross validation is used to find the optimal k value
odd k value is prefered to avoid ties in classification

# %%
KNN classification algorithm is a simple and effective machine learning algorithm used for classification tasks. It works by finding the k nearest neighbors to a given data point and assigning the class label based on the majority class among those neighbors. The choice of distance metric and the value of k can significantly impact the performance of the KNN algorithm.

# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

# %%
df["target"] = iris.target

# %%
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import pandas as pd

from sklearn.datasets import load_iris

# Load dataset
iris = load_iris()

# Convert into dataframe
df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

# Add target column
df["target"] = iris.target

# Display first 5 rows
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print(df.isnull().sum())
